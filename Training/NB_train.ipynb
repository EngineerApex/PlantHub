# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pickle

# Load data from CSV file
df = pd.read_csv('drive/MyDrive/Colab Notebooks/csv/Final.csv', header=None, names=['feat1', 'feat2', 'feat3', 'feat4', 'feat5', 'feat6', 'class'])

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df.drop('class', axis=1), df['class'], test_size=0.2, random_state=42)

# Train the model
model = GaussianNB()
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Calculate accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy:', accuracy)

with open('drive/MyDrive/Colab Notebooks/NB_train.pkl', 'wb') as file:
        pickle.dump(model, file)
# Out:
# Accuracy: 0.3975409836065574
